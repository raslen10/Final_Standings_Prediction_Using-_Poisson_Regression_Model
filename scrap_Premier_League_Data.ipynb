# %%
import pandas as pd
import requests
import json

# %%
# Headers pour les requêtes HTTP
headers = {
    "accept": "*/*",
    "accept-language": "fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7",
    "cache-control": "max-age=0",
    "cookie": "_lr_env_src_ats=false; _ga=GA1.1.518127049.1726214072; gcid_first=7437646c-78ec-4f9a-a9ad-f4c21a9e8c08; __browsiUID=6379de9b-fe77-4b3b-8824-f6e40b82e364; __qca=P0-951274957-1726214075703; __gads=ID=c94e0cda4c5c9052:T=1726214079:RT=1727368336:S=ALNI_Mb6P9HIj3mCNPksnwbpiqjaEwTKaA; __gpi=UID=00000efa18245580:T=1726214079:RT=1727368336:S=ALNI_MaNea2tIqCM-LO6uM3eUwIGwUIE7Q; __eoi=ID=7804ffe67b74ffe7:T=1726214079:RT=1727368336:S=AA-AfjYsQttp-gLQ8fIvrFNAlJWu; __browsiSessionID=d0f29983-b3c3-4786-b589-81b5446a5360&true&DEFAULT&tn&desktop-4.31.352&false; FCNEC=%5B%5B%22AKsRol8xKdu37hGGt11fQUprDbcJ7qTw0x8gom8ak1Y_xoqRxGA0FkkIfXd6_0h35aOEYaa4qvCeBYjlL3xWruDTzUZyJHvOG82HzfWHEg6zzsuDmknbrmDzT8R7ZTO07r7wbq03CGbn4ANkNi7kdJXUlBQHQIFumA%3D%3D%22%5D%5D; _ga_HNQ9P9MGZR=GS1.1.1727368332.14.1.1727368412.42.0.0",
    "if-none-match": 'W/"2d973d6709"',
    "priority": "u=1, i",
    "referer": "https://www.sofascore.com/fr/tournoi/football/england/premier-league/17",
    "sec-ch-ua": '"Google Chrome";v="129", "Not=A?Brand";v="8", "Chromium";v="129"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Windows"',
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Safari/537.36",
    "x-requested-with": "b9972d"
}

# Liste pour stocker les données des matches
matches = []

# Boucle sur les journées de 1 à 6
for round_number in range(1, 7):
    url = f"https://www.sofascore.com/api/v1/unique-tournament/17/season/61627/events/round/{round_number}"

    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        data = response.json()
        events = data.get("events", [])

        for event in events:
            home_team = event["homeTeam"]["name"]
            away_team = event["awayTeam"]["name"]
            home_goals = event["homeScore"]["current"]
            away_goals = event["awayScore"]["current"]

            matches.append({
                "home_team": home_team,
                "away_team": away_team,
                "home_goals": home_goals,
                "away_goals": away_goals
            })
    else:
        print(f"Failed to retrieve data for round {round_number}. Status code: {response.status_code}")

# Création d'un DataFrame à partir des données collectées
df = pd.DataFrame(matches)

# Affichage du DataFrame
print(df)
# Out:
# Failed to retrieve data for round 6. Status code: 304
#                  home_team               away_team  home_goals  away_goals
# 0        Manchester United                  Fulham           1           0
# 1             Ipswich Town               Liverpool           0           2
# 2                  Arsenal           Wolverhampton           2           0
# 3                  Everton  Brighton & Hove Albion           0           3
# 4         Newcastle United             Southampton           1           0
# 5        Nottingham Forest             Bournemouth           1           1
# 6          West Ham United             Aston Villa           1           2
# 7                Brentford          Crystal Palace           2           1
# 8                  Chelsea         Manchester City           0           2
# 9           Leicester City       Tottenham Hotspur           1           1
# 10  Brighton & Hove Albion       Manchester United           2           1
# ...

# %%
import requests
import json
import pandas as pd

# Headers pour les requêtes HTTP
headers = {
    "accept": "*/*",
    "accept-language": "fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7",
    "cache-control": "max-age=0",
    "cookie": "_lr_env_src_ats=false; _ga=GA1.1.518127049.1726214072; gcid_first=7437646c-78ec-4f9a-a9ad-f4c21a9e8c08; __browsiUID=6379de9b-fe77-4b3b-8824-f6e40b82e364; __qca=P0-951274957-1726214075703; __gads=ID=c94e0cda4c5c9052:T=1726214079:RT=1727368336:S=ALNI_Mb6P9HIj3mCNPksnwbpiqjaEwTKaA; __gpi=UID=00000efa18245580:T=1726214079:RT=1727368336:S=ALNI_MaNea2tIqCM-LO6uM3eUwIGwUIE7Q; __eoi=ID=7804ffe67b74ffe7:T=1726214079:RT=1727368336:S=AA-AfjYsQttp-gLQ8fIvrFNAlJWu; __browsiSessionID=d0f29983-b3c3-4786-b589-81b5446a5360&true&DEFAULT&tn&desktop-4.31.352&false; FCNEC=%5B%5B%22AKsRol8xKdu37hGGt11fQUprDbcJ7qTw0x8gom8ak1Y_xoqRxGA0FkkIfXd6_0h35aOEYaa4qvCeBYjlL3xWruDTzUZyJHvOG82HzfWHEg6zzsuDmknbrmDzT8R7ZTO07r7wbq03CGbn4ANkNi7kdJXUlBQHQIFumA%3D%3D%22%5D%5D; _ga_HNQ9P9MGZR=GS1.1.1727368332.14.1.1727368412.42.0.0",
    "if-none-match": 'W/"2d973d6709"',
    "priority": "u=1, i",
    "referer": "https://www.sofascore.com/fr/tournoi/football/england/premier-league/17",
    "sec-ch-ua": '"Google Chrome";v="129", "Not=A?Brand";v="8", "Chromium";v="129"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Windows"',
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Safari/537.36",
    "x-requested-with": "b9972d"
}

# IDs des saisons de 2020-2021 à 2024-2025
season_ids = {
    "2020-2021": 37036,
    "2021-2022": 41886,
    "2022-2023": 45560,
    "2023-2024": 52186,
    "2024-2025": 61627
}

# Liste pour stocker les données des matches
matches = []

# Boucle sur chaque saison et chaque journée
for season, season_id in season_ids.items():
    for round_number in range(1, 39):
        url = f"https://www.sofascore.com/api/v1/unique-tournament/17/season/{season_id}/events/round/{round_number}"

        response = requests.get(url, headers=headers)

        if response.status_code == 200:
            data = response.json()
            events = data.get("events", [])

            for event in events:
                home_team = event["homeTeam"]["name"]
                away_team = event["awayTeam"]["name"]
                home_goals = event["homeScore"].get("current", 0)
                away_goals = event["awayScore"].get("current", 0)

                matches.append({
                    "season": season,
                    "round": round_number,
                    "home_team": home_team,
                    "away_team": away_team,
                    "home_goals": home_goals,
                    "away_goals": away_goals
                })
        else:
            print(f"Failed to retrieve data for season {season}, round {round_number}. Status code: {response.status_code}")

# Création d'un DataFrame à partir des données collectées
df = pd.DataFrame(matches)

# Affichage du DataFrame
print(df)
# Out:
# Failed to retrieve data for season 2022-2023, round 1. Status code: 404
# Failed to retrieve data for season 2022-2023, round 2. Status code: 404
# Failed to retrieve data for season 2022-2023, round 3. Status code: 404
# Failed to retrieve data for season 2022-2023, round 4. Status code: 404
# Failed to retrieve data for season 2022-2023, round 5. Status code: 404
# Failed to retrieve data for season 2022-2023, round 6. Status code: 404
# Failed to retrieve data for season 2022-2023, round 7. Status code: 404
# Failed to retrieve data for season 2022-2023, round 8. Status code: 404
# Failed to retrieve data for season 2022-2023, round 9. Status code: 404
# Failed to retrieve data for season 2022-2023, round 10. Status code: 404
# Failed to retrieve data for season 2022-2023, round 11. Status code: 404
# Failed to retrieve data for season 2022-2023, round 12. Status code: 404
# Failed to retrieve data for season 2022-2023, round 13. Status code: 404
# ...

# %%
df[1247:]
# Out:
#          season  round          home_team               away_team  home_goals  \
# 1247  2024-2025      7     Crystal Palace               Liverpool           0
# 1248  2024-2025      7            Arsenal             Southampton           0
# 1249  2024-2025      7          Brentford           Wolverhampton           0
# 1250  2024-2025      7     Leicester City             Bournemouth           0
# 1251  2024-2025      7    Manchester City                  Fulham           0
# ...         ...    ...                ...                     ...         ...
# 1562  2024-2025     38   Newcastle United                 Everton           0
# 1563  2024-2025     38  Nottingham Forest                 Chelsea           0
# 1564  2024-2025     38        Southampton                 Arsenal           0
# 1565  2024-2025     38  Tottenham Hotspur  Brighton & Hove Albion           0
# 1566  2024-2025     38      Wolverhampton               Brentford           0
#
#       away_goals
# ...

# %%
# Filtrer le DataFrame pour conserver uniquement les lignes avant l'indice 1247
df_filtered = df[:1247]

# Enregistrer le DataFrame filtré dans un fichier CSV
df_filtered.to_csv('/content/drive/MyDrive/match_score_prediction/matches_filtered.csv', index=False)

# %%
# scrap matches to predit
# Headers pour les requêtes HTTP
headers = {
    "accept": "*/*",
    "accept-language": "fr-FR,fr;q=0.9,en-US;q=0.8,en;q=0.7",
    "cache-control": "max-age=0",
    "cookie": "_lr_env_src_ats=false; _ga=GA1.1.518127049.1726214072; gcid_first=7437646c-78ec-4f9a-a9ad-f4c21a9e8c08; __browsiUID=6379de9b-fe77-4b3b-8824-f6e40b82e364; __qca=P0-951274957-1726214075703; __gads=ID=c94e0cda4c5c9052:T=1726214079:RT=1727368336:S=ALNI_Mb6P9HIj3mCNPksnwbpiqjaEwTKaA; __gpi=UID=00000efa18245580:T=1726214079:RT=1727368336:S=ALNI_MaNea2tIqCM-LO6uM3eUwIGwUIE7Q; __eoi=ID=7804ffe67b74ffe7:T=1726214079:RT=1727368336:S=AA-AfjYsQttp-gLQ8fIvrFNAlJWu; __browsiSessionID=d0f29983-b3c3-4786-b589-81b5446a5360&true&DEFAULT&tn&desktop-4.31.352&false; FCNEC=%5B%5B%22AKsRol8xKdu37hGGt11fQUprDbcJ7qTw0x8gom8ak1Y_xoqRxGA0FkkIfXd6_0h35aOEYaa4qvCeBYjlL3xWruDTzUZyJHvOG82HzfWHEg6zzsuDmknbrmDzT8R7ZTO07r7wbq03CGbn4ANkNi7kdJXUlBQHQIFumA%3D%3D%22%5D%5D; _ga_HNQ9P9MGZR=GS1.1.1727368332.14.1.1727368412.42.0.0",
    "if-none-match": 'W/"2d973d6709"',
    "priority": "u=1, i",
    "referer": "https://www.sofascore.com/fr/tournoi/football/england/premier-league/17",
    "sec-ch-ua": '"Google Chrome";v="129", "Not=A?Brand";v="8", "Chromium";v="129"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Windows"',
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Safari/537.36",
    "x-requested-with": "b9972d"
}

# Liste pour stocker les données des matches
matches = []

# Boucle sur les journées de 1 à 6
for round_number in range(6, 39):
    url = f"https://www.sofascore.com/api/v1/unique-tournament/17/season/61627/events/round/{round_number}"

    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        data = response.json()
        events = data.get("events", [])

        for event in events:
            home_team = event["homeTeam"]["name"]
            away_team = event["awayTeam"]["name"]


            matches.append({
                "home_team": home_team,
                "away_team": away_team

            })
    else:
        print(f"Failed to retrieve data for round {round_number}. Status code: {response.status_code}")

# Création d'un DataFrame à partir des données collectées
df_test = pd.DataFrame(matches)
# Enregistrer le DataFrame filtré dans un fichier CSV
df_test.to_csv('/content/drive/MyDrive/match_score_prediction/matches_to_predites.csv', index=False)

# Affichage du DataFrame
print(df_test)
# Out:
# Failed to retrieve data for round 6. Status code: 304
#              home_team               away_team
# 0       Crystal Palace               Liverpool
# 1              Arsenal             Southampton
# 2            Brentford           Wolverhampton
# 3       Leicester City             Bournemouth
# 4      Manchester City                  Fulham
# ..                 ...                     ...
# 315   Newcastle United                 Everton
# 316  Nottingham Forest                 Chelsea
# 317        Southampton                 Arsenal
# 318  Tottenham Hotspur  Brighton & Hove Albion
# 319      Wolverhampton               Brentford
#
# [320 rows x 2 columns]
